# %% [markdown]
# # Evaluación Parcial 1 - Machine Learning
# ## Proyecto: Predicción y Preparación de Pandemias
# ### Fase 1 CRISP-DM: Business Understanding
#
# ---
#
# **📋 INFORMACIÓN DEL PROYECTO**
# - **Asignatura**: Machine Learning (MLY0100)
# - **Evaluación**: Parcial 1 (40% de la nota final)
# - **Metodología**: CRISP-DM
# - **Framework**: Kedro
# - **Fecha**: Noviembre 2025
#
# ---

# %%
# =============================================================================
# CELDA 1: SETUP KEDRO
# =============================================================================

# Cargar extensión de Kedro para Jupyter
# %load_ext kedro.ipython

print("="*70)
print("📋 PROYECTO: Predicción y Preparación de Pandemias")
print("="*70)
print("👥 Integrantes: [Escribe aquí los nombres del equipo]")
print("📅 Fecha: Noviembre 2025")
print("📚 Asignatura: Machine Learning (MLY0100)")
print("🎯 Evaluación: Parcial 1 - Business Understanding")
print("="*70)
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython
# ...
# 📋 PROYECTO: Predicción y Preparación de Pandemias
# ...
# 👥 Integrantes: [Escribe aquí los nombres del equipo]
# 📅 Fecha: Noviembre 2025
# 📚 Asignatura: Machine Learning (MLY0100)
# 🎯 Evaluación: Parcial 1 - Business Understanding
# ...

# %%
# =============================================================================
# CELDA 2: IMPORTAR LIBRERÍAS
# =============================================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Configuración de visualización
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

print("✅ Librerías cargadas correctamente")
# Out:
# ✅ Librerías cargadas correctamente

# %%
# =============================================================================
# CELDA 3: VERIFICAR CONTEXTO KEDRO
# =============================================================================

print("\n🔍 VERIFICACIÓN DEL PROYECTO KEDRO:")
print("="*70)
print(f"📁 Proyecto: {context.project_path}")
print(f"📦 Package: {context._package_name}")
print(f"🔧 Kedro versión: {context.__class__.__module__}")
print("="*70)

# Verificar datasets disponibles
print("\n📊 Datasets disponibles en el catálogo:")
available_datasets = [ds for ds in catalog.list() if not ds.startswith('params:')]
for i, dataset in enumerate(available_datasets[:10], 1):
    print(f"  {i}. {dataset}")
if len(available_datasets) > 10:
    print(f"  ... y {len(available_datasets) - 10} más")

print("\n✅ Contexto Kedro verificado correctamente")
# Out:
# 🔍 VERIFICACIÓN DEL PROYECTO KEDRO:
# ...
# 📁 Proyecto: D:\Maching\prediccion-pandemias\prediccion-preparacion-pandemias
# 📦 Package: prediccion_preparacion_pandemias
# 🔧 Kedro versión: kedro.framework.context.context
# ...
#
# 📊 Datasets disponibles en el catálogo:
#   1. covid_data_raw
#   2. vaccination_global_raw
#   3. vaccination_age_raw
#   4. vaccination_manufacturer_raw
#   5. covid_data_validated
#   6. vaccination_global_validated
#   7. vaccination_age_validated
#   8. vaccination_manufacturer_validated
#   9. covid_data_cleaned
#   10. vaccination_global_cleaned
#   ... y 6 más
#
# ✅ Contexto Kedro verificado correctamente

# %% [markdown]
# ---
# ## 1. DEFINICIÓN DEL PROBLEMA DE NEGOCIO
# ---

# %%
# =============================================================================
# 1.1 PROBLEMA DE NEGOCIO
# =============================================================================

print("="*70)
print("1. DEFINICIÓN DEL PROBLEMA DE NEGOCIO")
print("="*70)

problema_descripcion = """
🦠 CONTEXTO:
Las pandemias representan amenazas catastróficas para la salud global,
con impactos devastadores en sistemas de salud, economías y sociedades.
La pandemia de COVID-19 demostró que la preparación varía enormemente
entre países, pero actualmente NO existe un sistema objetivo y basado
en datos para predecir qué países estarán mejor preparados para futuras
emergencias sanitarias.

⚠️ PROBLEMAS ACTUALES:

1. EVALUACIONES SUBJETIVAS:
   - Índices basados en opiniones de expertos
   - Falta de validación empírica
   - Sesgos geográficos y políticos

2. DATOS ESTÁTICOS:
   - No capturan dinámicas temporales
   - Ignoran capacidad de respuesta real
   - No consideran efectividad de políticas

3. INFORMACIÓN INCOMPLETA:
   - Falta integración de múltiples fuentes
   - Indicadores parciales y aislados
   - Sin análisis de factores combinados

4. AUSENCIA DE SISTEMA PREDICTIVO:
   - No existe herramienta automatizada
   - Difícil escalabilidad
   - Sin capacidad de actualización continua

💡 OPORTUNIDAD:
Con los datos históricos de COVID-19 y campañas de vacunación,
podemos desarrollar un sistema de Machine Learning que:
- Evalúe objetivamente la preparación de países
- Identifique patrones de respuesta exitosa
- Prediga capacidades futuras basándose en evidencia
- Proporcione insights accionables para políticas públicas
"""

print(problema_descripcion)
# Out:
# ...
# 1. DEFINICIÓN DEL PROBLEMA DE NEGOCIO
# ...
#
# 🦠 CONTEXTO:
# Las pandemias representan amenazas catastróficas para la salud global,
# con impactos devastadores en sistemas de salud, economías y sociedades.
# La pandemia de COVID-19 demostró que la preparación varía enormemente
# entre países, pero actualmente NO existe un sistema objetivo y basado
# en datos para predecir qué países estarán mejor preparados para futuras
# emergencias sanitarias.
#
# ⚠️ PROBLEMAS ACTUALES:
#
# 1. EVALUACIONES SUBJETIVAS:
#    - Índices basados en opiniones de expertos
#    - Falta de validación empírica
#    - Sesgos geográficos y políticos
#
# 2. DATOS ESTÁTICOS:
#    - No capturan dinámicas temporales
#    - Ignoran capacidad de respuesta real
#    - No consideran efectividad de políticas
#
# 3. INFORMACIÓN INCOMPLETA:
#    - Falta integración de múltiples fuentes
#    - Indicadores parciales y aislados
#    - Sin análisis de factores combinados
#
# 4. AUSENCIA DE SISTEMA PREDICTIVO:
# ...

# %%
# =============================================================================
# 1.2 ESTRUCTURA DEL PROBLEMA
# =============================================================================

problema = {
    'contexto': 'Amenaza global de pandemias y necesidad de preparación',
    'problema_principal': 'Falta de sistema predictivo objetivo para evaluar preparación pandémica',
    'limitaciones_actuales': [
        'Evaluaciones subjetivas y poco científicas',
        'Datos estáticos que no capturan dinámicas',
        'Información fragmentada e incompleta',
        'Ausencia de automatización y escalabilidad'
    ],
    'stakeholders_afectados': [
        'Ministerios de Salud',
        'Organizaciones Internacionales (OMS, OPS)',
        'Gobiernos nacionales y regionales',
        'Población mundial'
    ],
    'impacto_potencial': [
        'Salvamento de vidas',
        'Optimización de recursos',
        'Mejora de políticas públicas',
        'Preparación proactiva'
    ]
}

print("\n📊 ESTRUCTURA DEL PROBLEMA:\n")
for key, value in problema.items():
    print(f"\n{key.upper().replace('_', ' ')}:")
    if isinstance(value, list):
        for item in value:
            print(f"  ✓ {item}")
    else:
        print(f"  {value}")
# Out:
# 📊 ESTRUCTURA DEL PROBLEMA:
#
#
# CONTEXTO:
#   Amenaza global de pandemias y necesidad de preparación
#
# PROBLEMA PRINCIPAL:
#   Falta de sistema predictivo objetivo para evaluar preparación pandémica
#
# LIMITACIONES ACTUALES:
#   ✓ Evaluaciones subjetivas y poco científicas
#   ✓ Datos estáticos que no capturan dinámicas
#   ✓ Información fragmentada e incompleta
#   ✓ Ausencia de automatización y escalabilidad
#
# STAKEHOLDERS AFECTADOS:
#   ✓ Ministerios de Salud
#   ✓ Organizaciones Internacionales (OMS, OPS)
#   ✓ Gobiernos nacionales y regionales
#   ✓ Población mundial
#
# IMPACTO POTENCIAL:
#   ✓ Salvamento de vidas
#   ✓ Optimización de recursos
#   ✓ Mejora de políticas públicas
#   ✓ Preparación proactiva

# %% [markdown]
# ---
# ## 2. OBJETIVOS DEL PROYECTO
# ---

# %%
# =============================================================================
# 2.1 OBJETIVO PRINCIPAL
# =============================================================================

print("\n" + "="*70)
print("2. OBJETIVOS DEL PROYECTO")
print("="*70)

objetivo_principal = """
🎯 OBJETIVO PRINCIPAL:

Desarrollar un sistema predictivo de Machine Learning que evalúe la
preparación de países ante futuras pandemias, utilizando datos históricos
de COVID-19 y campañas de vacunación, para:

1. CLASIFICAR países según su nivel de preparación (Alto, Medio, Bajo)

2. PREDECIR capacidad del sistema de salud mediante un score continuo (0-100)

3. IDENTIFICAR patrones y factores críticos que determinan una respuesta
   exitosa ante emergencias sanitarias

4. PROPORCIONAR insights accionables para:
   ✓ Intervenciones preventivas tempranas
   ✓ Asignación eficiente de recursos internacionales
   ✓ Diseño de políticas públicas basadas en evidencia
   ✓ Preparación proactiva ante emergencias futuras

📊 VALOR ESPERADO:

Para OMS y organizaciones internacionales:
  → Priorización objetiva de apoyo y recursos
  → Monitoreo continuo de preparación global
  → Identificación temprana de vulnerabilidades

Para gobiernos nacionales:
  → Diagnóstico de fortalezas y debilidades
  → Benchmarking con países similares
  → Guía para inversión en salud pública

Para investigadores:
  → Base de conocimiento reproducible
  → Framework extensible para nuevas pandemias
  → Metodología científica validada
"""

print(objetivo_principal)
# Out:
# ...
# 2. OBJETIVOS DEL PROYECTO
# ...
#
# 🎯 OBJETIVO PRINCIPAL:
#
# Desarrollar un sistema predictivo de Machine Learning que evalúe la
# preparación de países ante futuras pandemias, utilizando datos históricos
# de COVID-19 y campañas de vacunación, para:
#
# 1. CLASIFICAR países según su nivel de preparación (Alto, Medio, Bajo)
#
# 2. PREDECIR capacidad del sistema de salud mediante un score continuo (0-100)
#
# 3. IDENTIFICAR patrones y factores críticos que determinan una respuesta
#    exitosa ante emergencias sanitarias
#
# 4. PROPORCIONAR insights accionables para:
#    ✓ Intervenciones preventivas tempranas
#    ✓ Asignación eficiente de recursos internacionales
#    ✓ Diseño de políticas públicas basadas en evidencia
#    ✓ Preparación proactiva ante emergencias futuras
#
# 📊 VALOR ESPERADO:
#
# Para OMS y organizaciones internacionales:
#   → Priorización objetiva de apoyo y recursos
#   → Monitoreo continuo de preparación global
#   → Identificación temprana de vulnerabilidades
#
# ...

# %%
# =============================================================================
# 2.2 OBJETIVOS ESPECÍFICOS (SMART)
# =============================================================================

objetivos_smart = {
    1: {
        'objetivo': 'Cuantificar Preparación Pandémica',
        'especifico': 'Crear índice de preparación 0-100 para 150+ países',
        'medible': 'Índice numérico validado con datos históricos',
        'alcanzable': 'Basado en 4 datasets con 700K+ registros disponibles',
        'relevante': 'Permite comparación objetiva entre países y regiones',
        'tiempo': '4 semanas (Evaluación Parcial 1)',
        'kpi': 'Índice generado para ≥150 países'
    },
    2: {
        'objetivo': 'Predecir Velocidad de Respuesta',
        'especifico': 'Estimar días necesarios para alcanzar 70% cobertura vacunal',
        'medible': 'Error absoluto medio (MAE) < 30 días',
        'alcanzable': 'Con datos históricos de vacunación de 200+ países',
        'relevante': 'Crítico para planificación logística y recursos',
        'tiempo': '8 semanas (Evaluación Parcial 2)',
        'kpi': 'MAE < 30 días en test set'
    },
    3: {
        'objetivo': 'Clasificar Estrategias Nacionales',
        'especifico': 'Identificar 5-7 arquetipos estratégicos de respuesta',
        'medible': 'Clusters bien definidos (Silhouette Score > 0.5)',
        'alcanzable': 'Mediante clustering no supervisado (K-Means, DBSCAN)',
        'relevante': 'Permite aprender de mejores prácticas globales',
        'tiempo': '12 semanas (Evaluación Parcial 3)',
        'kpi': '5-7 clusters con Silhouette > 0.5'
    },
    4: {
        'objetivo': 'Identificar Factores Críticos',
        'especifico': 'Determinar top 10 variables que predicen preparación',
        'medible': 'Feature importance scores + análisis de correlación',
        'alcanzable': 'Con 30-45 features engineered y modelos interpretables',
        'relevante': 'Guía políticas públicas y asignación de presupuesto',
        'tiempo': '8 semanas (Evaluación Parcial 2)',
        'kpi': 'Top 10 features con importance > 5%'
    },
    5: {
        'objetivo': 'Desarrollar Sistema Reproducible',
        'especifico': 'Pipeline MLOps completo con Kedro + Airflow + DVC + Docker',
        'medible': 'Sistema ejecutable por terceros sin errores',
        'alcanzable': 'Siguiendo mejores prácticas de MLOps',
        'relevante': 'Permite actualización continua y escalabilidad',
        'tiempo': '12 semanas (Evaluación Parcial 3)',
        'kpi': 'kedro run sin errores + Docker funcional'
    }
}

print("\n🎯 OBJETIVOS SMART DEL PROYECTO:")
print("="*70)

for num, obj in objetivos_smart.items():
    print(f"\n{num}. {obj['objetivo'].upper()}")
    print(f"   📍 Específico: {obj['especifico']}")
    print(f"   📏 Medible: {obj['medible']}")
    print(f"   ✅ Alcanzable: {obj['alcanzable']}")
    print(f"   🎯 Relevante: {obj['relevante']}")
    print(f"   ⏰ Tiempo: {obj['tiempo']}")
    print(f"   📊 KPI: {obj['kpi']}")
# Out:
# 🎯 OBJETIVOS SMART DEL PROYECTO:
# ...
#
# 1. CUANTIFICAR PREPARACIÓN PANDÉMICA
#    📍 Específico: Crear índice de preparación 0-100 para 150+ países
#    📏 Medible: Índice numérico validado con datos históricos
#    ✅ Alcanzable: Basado en 4 datasets con 700K+ registros disponibles
#    🎯 Relevante: Permite comparación objetiva entre países y regiones
#    ⏰ Tiempo: 4 semanas (Evaluación Parcial 1)
#    📊 KPI: Índice generado para ≥150 países
#
# 2. PREDECIR VELOCIDAD DE RESPUESTA
#    📍 Específico: Estimar días necesarios para alcanzar 70% cobertura vacunal
#    📏 Medible: Error absoluto medio (MAE) < 30 días
#    ✅ Alcanzable: Con datos históricos de vacunación de 200+ países
#    🎯 Relevante: Crítico para planificación logística y recursos
#    ⏰ Tiempo: 8 semanas (Evaluación Parcial 2)
#    📊 KPI: MAE < 30 días en test set
#
# 3. CLASIFICAR ESTRATEGIAS NACIONALES
#    📍 Específico: Identificar 5-7 arquetipos estratégicos de respuesta
# ...

# %% [markdown]
# ---
# ## 3. STAKEHOLDERS Y USUARIOS
# ---

# %%
# =============================================================================
# 3. STAKEHOLDERS Y USUARIOS
# =============================================================================

print("\n" + "="*70)
print("3. STAKEHOLDERS Y USUARIOS")
print("="*70)

stakeholders = {
    'Organizaciones Internacionales': {
        'ejemplos': ['OMS', 'OPS', 'Banco Mundial', 'ONU'],
        'intereses': [
            'Priorización de recursos limitados',
            'Monitoreo de preparación global',
            'Coordinación de respuesta internacional'
        ],
        'uso_esperado': [
            'Identificar países que necesitan apoyo urgente',
            'Asignar fondos y recursos estratégicamente',
            'Evaluar efectividad de programas de apoyo'
        ]
    },
    'Ministerios de Salud': {
        'ejemplos': ['MINSAL Chile', 'CDC USA', 'NHS UK'],
        'intereses': [
            'Fortalecer capacidad de respuesta nacional',
            'Justificar inversión en salud pública',
            'Aprender de mejores prácticas internacionales'
        ],
        'uso_esperado': [
            'Diagnóstico de fortalezas y debilidades',
            'Benchmarking con países similares',
            'Planificación de inversiones prioritarias'
        ]
    },
    'Gobiernos Nacionales': {
        'ejemplos': ['Presidencias', 'Ministerios de Hacienda'],
        'intereses': [
            'Proteger economía nacional',
            'Minimizar impacto social de pandemias',
            'Asegurar continuidad de servicios esenciales'
        ],
        'uso_esperado': [
            'Evaluación de riesgos nacionales',
            'Priorización de presupuesto sanitario',
            'Diseño de políticas preventivas'
        ]
    },
    'Comunidad Científica': {
        'ejemplos': ['Investigadores', 'Epidemiólogos', 'Data Scientists'],
        'intereses': [
            'Comprender factores de preparación pandémica',
            'Desarrollar metodologías reproducibles',
            'Publicar hallazgos científicos'
        ],
        'uso_esperado': [
            'Base de datos para investigación',
            'Framework extensible para nuevos estudios',
            'Validación de hipótesis epidemiológicas'
        ]
    },
    'Sector Privado': {
        'ejemplos': ['Farmacéuticas', 'Aseguradoras', 'Hospitales privados'],
        'intereses': [
            'Planificación de capacidad',
            'Gestión de riesgos',
            'Identificación de oportunidades de negocio'
        ],
        'uso_esperado': [
            'Evaluación de mercados para inversión',
            'Análisis de demanda futura',
            'Estrategias de expansión'
        ]
    }
}

for stakeholder, info in stakeholders.items():
    print(f"\n👥 {stakeholder.upper()}")
    print(f"   Ejemplos: {', '.join(info['ejemplos'])}")
    print(f"\n   💼 Intereses:")
    for interes in info['intereses']:
        print(f"      • {interes}")
    print(f"\n   🎯 Uso esperado del sistema:")
    for uso in info['uso_esperado']:
        print(f"      ✓ {uso}")
# Out:
# ...
# 3. STAKEHOLDERS Y USUARIOS
# ...
#
# 👥 ORGANIZACIONES INTERNACIONALES
#    Ejemplos: OMS, OPS, Banco Mundial, ONU
#
#    💼 Intereses:
#       • Priorización de recursos limitados
#       • Monitoreo de preparación global
#       • Coordinación de respuesta internacional
#
#    🎯 Uso esperado del sistema:
#       ✓ Identificar países que necesitan apoyo urgente
#       ✓ Asignar fondos y recursos estratégicamente
#       ✓ Evaluar efectividad de programas de apoyo
#
# 👥 MINISTERIOS DE SALUD
#    Ejemplos: MINSAL Chile, CDC USA, NHS UK
#
#    💼 Intereses:
#       • Fortalecer capacidad de respuesta nacional
#       • Justificar inversión en salud pública
#       • Aprender de mejores prácticas internacionales
#
#    🎯 Uso esperado del sistema:
#       ✓ Diagnóstico de fortalezas y debilidades
#       ✓ Benchmarking con países similares
#       ✓ Planificación de inversiones prioritarias
#
# 👥 GOBIERNOS NACIONALES
#    Ejemplos: Presidencias, Ministerios de Hacienda
#
#    💼 Intereses:
# ...

# %% [markdown]
# ---
# ## 4. DEFINICIÓN DE TARGETS
# ---

# %%
# =============================================================================
# 4. DEFINICIÓN DE VARIABLES TARGET
# =============================================================================

print("\n" + "="*70)
print("4. DEFINICIÓN DE VARIABLES TARGET")
print("="*70)

targets = {
    'Target 1: Nivel de Preparación (Clasificación)': {
        'tipo': 'Variable categórica ordinal',
        'nombre_variable': 'preparedness_level',
        'clases': {
            'Alto': 'Score >= 0.7 - Países con excelente capacidad de respuesta',
            'Medio': '0.4 <= Score < 0.7 - Países con capacidad moderada',
            'Bajo': 'Score < 0.4 - Países que requieren apoyo urgente'
        },
        'factores_considerados': [
            'Tasa de vacunación alcanzada',
            'Tasa de mortalidad (invertida)',
            'Capacidad hospitalaria per cápita',
            'Velocidad de respuesta inicial',
            'Efectividad de políticas implementadas'
        ],
        'formula_score': 'Score = promedio_ponderado(factores normalizados 0-1)',
        'justificacion_negocio': [
            'Permite priorización clara de recursos',
            'Facilita comunicación con stakeholders no técnicos',
            'Identifica países en riesgo crítico',
            'Base para alertas tempranas'
        ],
        'uso_esperado': [
            'Clasificación automática de nuevos países',
            'Sistema de alertas para OMS',
            'Dashboard de monitoreo global'
        ]
    },
    'Target 2: Capacidad del Sistema de Salud (Regresión)': {
        'tipo': 'Variable numérica continua',
        'nombre_variable': 'healthcare_capacity_score',
        'rango': '0-100 puntos',
        'interpretacion': {
            '0-25': 'Capacidad crítica - Colapso inminente',
            '25-50': 'Capacidad limitada - Alto riesgo',
            '50-75': 'Capacidad moderada - Manejo aceptable',
            '75-100': 'Capacidad robusta - Excelente preparación'
        },
        'factores_considerados': [
            'Camas hospitalarias por 1000 habitantes',
            'Capacidad de cuidados intensivos (UCI)',
            'Personal médico disponible (médicos, enfermeras)',
            'PIB per cápita (proxy de recursos)',
            'Infraestructura sanitaria'
        ],
        'formula_score': 'Score = Σ(factores normalizados) / n_factores * 100',
        'justificacion_negocio': [
            'Predicción continua permite planificación granular',
            'Identifica mejoras marginales necesarias',
            'Permite tracking de progreso en el tiempo',
            'Base para modelos predictivos avanzados'
        ],
        'uso_esperado': [
            'Predicción de capacidad futura',
            'Simulación de escenarios de crisis',
            'Estimación de inversión necesaria'
        ]
    }
}

for target_name, target_info in targets.items():
    print(f"\n🎯 {target_name}")
    print("   " + "="*65)
    print(f"   Tipo: {target_info['tipo']}")
    print(f"   Variable: {target_info['nombre_variable']}")
    
    if 'clases' in target_info:
        print(f"\n   📊 Clases:")
        for clase, desc in target_info['clases'].items():
            print(f"      • {clase}: {desc}")
    
    if 'rango' in target_info:
        print(f"\n   📏 Rango: {target_info['rango']}")
        print(f"\n   📈 Interpretación:")
        for rango, desc in target_info['interpretacion'].items():
            print(f"      • {rango}: {desc}")
    
    print(f"\n   🔍 Factores considerados:")
    for factor in target_info['factores_considerados']:
        print(f"      ✓ {factor}")
    
    print(f"\n   🧮 Fórmula: {target_info['formula_score']}")
    
    print(f"\n   💼 Justificación de negocio:")
    for just in target_info['justificacion_negocio']:
        print(f"      • {just}")
    
    print(f"\n   🎯 Uso esperado:")
    for uso in target_info['uso_esperado']:
        print(f"      → {uso}")
# Out:
# ...
# 4. DEFINICIÓN DE VARIABLES TARGET
# ...
#
# 🎯 Target 1: Nivel de Preparación (Clasificación)
# ...
#    Tipo: Variable categórica ordinal
#    Variable: preparedness_level
#
#    📊 Clases:
#       • Alto: Score >= 0.7 - Países con excelente capacidad de respuesta
#       • Medio: 0.4 <= Score < 0.7 - Países con capacidad moderada
#       • Bajo: Score < 0.4 - Países que requieren apoyo urgente
#
#    🔍 Factores considerados:
#       ✓ Tasa de vacunación alcanzada
#       ✓ Tasa de mortalidad (invertida)
#       ✓ Capacidad hospitalaria per cápita
#       ✓ Velocidad de respuesta inicial
#       ✓ Efectividad de políticas implementadas
#
#    🧮 Fórmula: Score = promedio_ponderado(factores normalizados 0-1)
#
#    💼 Justificación de negocio:
#       • Permite priorización clara de recursos
#       • Facilita comunicación con stakeholders no técnicos
#       • Identifica países en riesgo crítico
#       • Base para alertas tempranas
#
#    🎯 Uso esperado:
# ...

# %% [markdown]
# ---
# ## 5. RECURSOS Y DATOS DISPONIBLES
# ---

# %%
# =============================================================================
# 5. RECURSOS Y DATOS DISPONIBLES
# =============================================================================

print("\n" + "="*70)
print("5. RECURSOS Y DATOS DISPONIBLES")
print("="*70)

recursos = {
    'Datasets': {
        'COVID-19 Compact': {
            'registros_aprox': '~400,000',
            'variables': 61,
            'cobertura': '200+ países',
            'periodo': '2020-2023',
            'contenido': [
                'Casos diarios y acumulados',
                'Muertes diarias y acumuladas',
                'Pruebas realizadas',
                'Hospitalizaciones y UCI',
                'Variables socioeconómicas',
                'Indicadores de salud pública'
            ],
            'calidad': 'Media-Alta (missing values ~30-50% en algunas columnas)'
        },
        'Vacunación Global': {
            'registros_aprox': '~150,000',
            'variables': 29,
            'cobertura': '200+ países',
            'periodo': '2021-2023',
            'contenido': [
                'Dosis administradas (total, diarias)',
                'Personas vacunadas (1 dosis, completas)',
                'Dosis de refuerzo (boosters)',
                'Tasas de cobertura por población',
                'Velocidad de vacunación'
            ],
            'calidad': 'Media (missing values ~40-60% en algunas variables)'
        },
        'Vacunación por Edad': {
            'registros_aprox': '~100,000',
            'variables': 15,
            'cobertura': '150+ países',
            'periodo': '2021-2023',
            'contenido': [
                'Cobertura por grupos etarios',
                'Priorización etaria',
                'Efectividad diferencial'
            ],
            'calidad': 'Media-Baja (datos limitados para muchos países)'
        },
        'Vacunación por Fabricante': {
            'registros_aprox': '~100,000',
            'variables': 12,
            'cobertura': '150+ países',
            'periodo': '2021-2023',
            'contenido': [
                'Distribución por marca',
                'Pfizer, Moderna, AstraZeneca, etc.',
                'Disponibilidad regional'
            ],
            'calidad': 'Media (datos parciales)'
        }
    },
    'Tecnologías': {
        'Framework': 'Kedro 0.18.14',
        'Lenguaje': 'Python 3.8+',
        'ML': 'scikit-learn, numpy, pandas',
        'Visualización': 'matplotlib, seaborn, plotly',
        'MLOps_EP2': 'DVC, Airflow, Docker',
        'MLOps_EP3': 'MLflow, Feature Store'
    },
    'Equipo': {
        'estudiantes': 2,
        'tiempo_disponible': '4 semanas por evaluación parcial',
        'habilidades': [
            'Python',
            'Machine Learning',
            'Data Engineering',
            'Visualización de datos'
        ]
    }
}

# Mostrar información de datasets
print("\n📊 DATASETS DISPONIBLES:")
print("="*70)

total_registros = 0
for dataset_name, dataset_info in recursos['Datasets'].items():
    print(f"\n📁 {dataset_name}")
    print(f"   Registros: {dataset_info['registros_aprox']}")
    print(f"   Variables: {dataset_info['variables']}")
    print(f"   Cobertura: {dataset_info['cobertura']}")
    print(f"   Período: {dataset_info['periodo']}")
    print(f"   Calidad: {dataset_info['calidad']}")
    print(f"\n   Contenido:")
    for item in dataset_info['contenido']:
        print(f"      • {item}")

print("\n💻 TECNOLOGÍAS:")
print("="*70)
for tech, value in recursos['Tecnologías'].items():
    print(f"   {tech}: {value}")

print("\n👥 EQUIPO:")
print("="*70)
for key, value in recursos['Equipo'].items():
    if isinstance(value, list):
        print(f"   {key}:")
        for item in value:
            print(f"      • {item}")
    else:
        print(f"   {key}: {value}")

print("\n📈 RESUMEN DE DATOS:")
print("="*70)
print(f"   Total estimado de registros: ~750,000")
print(f"   Total de variables únicas: ~120")
print(f"   Países cubiertos: 200+")
print(f"   Período temporal: 2020-2023 (3+ años)")
print(f"   Volumen de datos: ~500MB-1GB")
# Out:
# ...
# 5. RECURSOS Y DATOS DISPONIBLES
# ...
#
# 📊 DATASETS DISPONIBLES:
# ...
#
# 📁 COVID-19 Compact
#    Registros: ~400,000
#    Variables: 61
#    Cobertura: 200+ países
#    Período: 2020-2023
#    Calidad: Media-Alta (missing values ~30-50% en algunas columnas)
#
#    Contenido:
#       • Casos diarios y acumulados
#       • Muertes diarias y acumuladas
#       • Pruebas realizadas
#       • Hospitalizaciones y UCI
#       • Variables socioeconómicas
#       • Indicadores de salud pública
#
# 📁 Vacunación Global
#    Registros: ~150,000
#    Variables: 29
#    Cobertura: 200+ países
#    Período: 2021-2023
#    Calidad: Media (missing values ~40-60% en algunas variables)
#
#    Contenido:
#       • Dosis administradas (total, diarias)
#       • Personas vacunadas (1 dosis, completas)
#       • Dosis de refuerzo (boosters)
#       • Tasas de cobertura por población
#       • Velocidad de vacunación
#
# 📁 Vacunación por Edad
#    Registros: ~100,000
#    Variables: 15
#    Cobertura: 150+ países
# ...

# %% [markdown]
# ---
# ## 6. PLAN DEL PROYECTO
# ---

# %%
# =============================================================================
# 6. PLAN DEL PROYECTO (CRONOGRAMA)
# =============================================================================

print("\n" + "="*70)
print("6. PLAN DEL PROYECTO")
print("="*70)

plan_proyecto = {
    'Evaluación Parcial 1 (4 semanas)': {
        'Semana 1': {
            'Fase': 'Setup y Comprensión del Negocio',
            'Actividades': [
                '✓ Configurar proyecto Kedro',
                '✓ Definir objetivos y stakeholders',
                '✓ Cargar y validar los 4 datasets',
                '✓ Configurar catalog.yml y parameters.yml',
                '✓ Crear pipeline de validación',
                '✓ Notebook 1: Business Understanding'
            ],
            'Entregables': [
                'Proyecto Kedro iniciado',
                'Datasets cargados y validados',
                'Objetivos documentados'
            ]
        },
        'Semana 2': {
            'Fase': 'Comprensión de los Datos (EDA)',
            'Actividades': [
                'Análisis exploratorio exhaustivo',
                'Análisis de missing values',
                'Análisis de correlaciones',
                'Identificar patrones temporales',
                'Análisis de outliers',
                'Notebook 2: Data Understanding'
            ],
            'Entregables': [
                'Notebook EDA completo',
                'Visualizaciones profesionales',
                'Reporte de calidad de datos'
            ]
        },
        'Semana 3': {
            'Fase': 'Preparación de los Datos',
            'Actividades': [
                'Limpieza de datos (missing, outliers)',
                'Feature engineering (30-45 features)',
                'Integración de los 4 datasets',
                'Creación de variables target',
                'Pipeline de data engineering',
                'Notebook 3: Data Preparation'
            ],
            'Entregables': [
                'Datos limpios y transformados',
                'Master dataset integrado',
                'Targets definidos y validados'
            ]
        },
        'Semana 4': {
            'Fase': 'Integración y Entrega',
            'Actividades': [
                'Documentación final (README)',
                'Testing de pipelines',
                'Validación de reproducibilidad',
                'Control de versiones (Git)',
                'Preparar presentación',
                'Revisión de rúbrica'
            ],
            'Entregables': [
                'Proyecto completo entregado',
                'Repositorio Git publicado',
                'Nota objetivo: 7.0'
            ]
        }
    },
    'Evaluación Parcial 2 (4 semanas)': {
        'Semana 1-2': {
            'Fase': 'Modelado Supervisado',
            'Actividades': [
                '≥5 modelos de clasificación',
                '≥5 modelos de regresión',
                'GridSearchCV + Cross-Validation (k≥5)',
                'Comparación de métricas'
            ]
        },
        'Semana 3': {
            'Fase': 'MLOps Infrastructure',
            'Actividades': [
                'Integrar DVC (datos, modelos, métricas)',
                'Crear DAGs de Airflow',
                'Dockerizar proyecto'
            ]
        },
        'Semana 4': {
            'Fase': 'Defensa Técnica',
            'Actividades': [
                'Documentación técnica',
                'Preparar presentación (10 min)',
                'Defensa oral'
            ]
        }
    },
    'Evaluación Parcial 3 (4 semanas)': {
        'Semana 1-2': {
            'Fase': 'Aprendizaje No Supervisado',
            'Actividades': [
                '≥3 algoritmos de clustering',
                '≥2 técnicas de reducción dimensional',
                'Análisis de patrones'
            ]
        },
        'Semana 3': {
            'Fase': 'Integración Final',
            'Actividades': [
                'Pipeline end-to-end completo',
                'Dashboard interactivo',
                'Reporte final'
            ]
        },
        'Semana 4': {
            'Fase': 'Presentación Final',
            'Actividades': [
                'Presentación (15-20 min)',
                'Demo en vivo',
                'Defensa técnica'
            ]
        }
    }
}

# Mostrar plan por evaluación
for evaluacion, fases in plan_proyecto.items():
    print(f"\n📅 {evaluacion}")
    print("   " + "="*65)
    
    for periodo, detalles in fases.items():
        print(f"\n   {periodo}")
        print(f"   Fase: {detalles['Fase']}")
        
        if 'Actividades' in detalles:
            print(f"\n   Actividades:")
            for act in detalles['Actividades']:
                print(f"      {act}")
        
        if 'Entregables' in detalles:
            print(f"\n   📦 Entregables:")
            for ent in detalles['Entregables']:
                print(f"      → {ent}")

# Timeline visual
print("\n\n📊 TIMELINE VISUAL (12 semanas totales):")
print("="*70)
print("""
EP1: Semanas 1-4   [████████████████░░░░░░░░░░░░░░░░░░░░]
     └─> Kedro + CRISP-DM (Fases 1-3)

EP2: Semanas 5-8   [░░░░░░░░░░░░░░░░████████████████░░░░]
     └─> Supervisado + DVC + Airflow + Docker

EP3: Semanas 9-12  [░░░░░░░░░░░░░░░░░░░░░░░░░░░░████████]
     └─> No Supervisado + Integración Final
""")
# Out:
# ...
# 6. PLAN DEL PROYECTO
# ...
#
# 📅 Evaluación Parcial 1 (4 semanas)
# ...
#
#    Semana 1
#    Fase: Setup y Comprensión del Negocio
#
#    Actividades:
#       ✓ Configurar proyecto Kedro
#       ✓ Definir objetivos y stakeholders
#       ✓ Cargar y validar los 4 datasets
#       ✓ Configurar catalog.yml y parameters.yml
#       ✓ Crear pipeline de validación
#       ✓ Notebook 1: Business Understanding
#
#    📦 Entregables:
#       → Proyecto Kedro iniciado
#       → Datasets cargados y validados
#       → Objetivos documentados
#
#    Semana 2
#    Fase: Comprensión de los Datos (EDA)
#
#    Actividades:
#       Análisis exploratorio exhaustivo
#       Análisis de missing values
#       Análisis de correlaciones
#       Identificar patrones temporales
#       Análisis de outliers
#       Notebook 2: Data Understanding
#
#    📦 Entregables:
#       → Notebook EDA completo
#       → Visualizaciones profesionales
#       → Reporte de calidad de datos
#
#    Semana 3
# ...

# %% [markdown]
# ---
# ## 7. CRITERIOS DE ÉXITO
# ---

# %%
# =============================================================================
# 7. CRITERIOS DE ÉXITO
# =============================================================================

print("\n" + "="*70)
print("7. CRITERIOS DE ÉXITO")
print("="*70)

criterios = {
    'Técnicos (Evaluación Parcial 1)': [
        'kedro run ejecuta sin errores',
        'Código sigue PEP8 y mejores prácticas',
        '3+ pipelines implementados (validación, limpieza, integración)',
        'Documentación completa (README, docstrings, notebooks)',
        '4 datasets correctamente integrados',
        '30-45 features derivadas',
        'Missing values < 5% en datos finales',
        'Proyecto completamente reproducible'
    ],
    'Técnicos (Evaluación Parcial 2)': [
        '≥5 modelos de clasificación implementados',
        '≥5 modelos de regresión implementados',
        'GridSearchCV + CV (k≥5) aplicado',
        'DVC versionando datos y modelos',
        'Airflow DAG funcional y documentado',
        'Docker imagen reproducible',
        'Defensa técnica exitosa'
    ],
    'Técnicos (Evaluación Parcial 3)': [
        '≥3 algoritmos de clustering implementados',
        '≥2 técnicas de reducción dimensional',
        'Pipeline end-to-end completo',
        'Sistema ejecutable en Docker sin errores',
        'Presentación profesional y defensa exitosa'
    ],
    'De Negocio': [
        'Accuracy > 70% en clasificación de preparación',
        'R² > 0.6 en regresión de capacidad de salud',
        'MAE < 30 días en predicción de velocidad de respuesta',
        '5-7 clusters significativos identificados',
        'Silhouette Score > 0.5 en clustering',
        'Top 10 features críticas identificadas',
        'Insights accionables para políticas públicas',
        'Sistema útil para stakeholders reales'
    ],
    'Académicos': [
        'Nota objetivo: 7.0 en cada evaluación parcial',
        'EP1: Entrega 24 Noviembre 2025',
        'EP2: Entrega + Defensa (4 semanas después)',
        'EP3: Entrega + Presentación Final (8 semanas después)',
        'Trabajo balanceado entre integrantes del equipo',
        'Cumplimiento de todos los requisitos de rúbrica',
        'Reproducibilidad total del proyecto',
        'Documentación de nivel profesional'
    ],
    'De Calidad': [
        'Código limpio y bien estructurado',
        'Tests unitarios (opcional pero recomendado)',
        'Sin datos sensibles en repositorio',
        'Commits descriptivos y frecuentes',
        '.gitignore configurado correctamente',
        'requirements.txt actualizado',
        'Pipelines modulares y reutilizables',
        'Visualizaciones profesionales'
    ]
}

for categoria, items in criterios.items():
    print(f"\n✅ {categoria}:")
    print("   " + "="*65)
    for i, item in enumerate(items, 1):
        print(f"   {i:2d}. {item}")

# Matriz de éxito
print("\n\n📊 MATRIZ DE ÉXITO:")
print("="*70)

matriz_exito = pd.DataFrame({
    'Evaluación': ['EP1', 'EP2', 'EP3'],
    'Ponderación': ['40%', '40%', '30%'],
    'Nota Objetivo': [7.0, 7.0, 7.0],
    'Componente Principal': [
        'Kedro + CRISP-DM (Fases 1-3)',
        'Supervisado + MLOps',
        'No Supervisado + Integración'
    ],
    'Métrica Clave': [
        'Reproducibilidad 100%',
        'Accuracy > 70%, R² > 0.6',
        'Silhouette > 0.5'
    ]
})

display(matriz_exito)

print("\n🎯 Nota final asignatura = 0.4*EP1 + 0.4*EP2 + 0.3*EP3")
print(f"🎯 Nota objetivo total: 7.0 × 0.4 + 7.0 × 0.4 + 7.0 × 0.3 = 6.7")
# Out:
# ...
# 7. CRITERIOS DE ÉXITO
# ...
#
# ✅ Técnicos (Evaluación Parcial 1):
# ...
#     1. kedro run ejecuta sin errores
#     2. Código sigue PEP8 y mejores prácticas
#     3. 3+ pipelines implementados (validación, limpieza, integración)
#     4. Documentación completa (README, docstrings, notebooks)
#     5. 4 datasets correctamente integrados
#     6. 30-45 features derivadas
#     7. Missing values < 5% en datos finales
#     8. Proyecto completamente reproducible
#
# ✅ Técnicos (Evaluación Parcial 2):
# ...
#     1. ≥5 modelos de clasificación implementados
#     2. ≥5 modelos de regresión implementados
#     3. GridSearchCV + CV (k≥5) aplicado
#     4. DVC versionando datos y modelos
#     5. Airflow DAG funcional y documentado
#     6. Docker imagen reproducible
#     7. Defensa técnica exitosa
#
# ✅ Técnicos (Evaluación Parcial 3):
# ...
#     1. ≥3 algoritmos de clustering implementados
#     2. ≥2 técnicas de reducción dimensional
#     3. Pipeline end-to-end completo
# ...

# %% [markdown]
# ---
# ## 8. RIESGOS Y MITIGACIÓN
# ---

# %%
# =============================================================================
# 8. ANÁLISIS DE RIESGOS Y ESTRATEGIAS DE MITIGACIÓN
# =============================================================================

print("\n" + "="*70)
print("8. RIESGOS Y ESTRATEGIAS DE MITIGACIÓN")
print("="*70)

riesgos = {
    'Calidad de Datos': {
        'probabilidad': 'Alta',
        'impacto': 'Alto',
        'descripcion': 'Missing values >50% en algunas columnas críticas',
        'mitigacion': [
            'Estrategias diferenciadas de imputación',
            'Forward-fill para series temporales',
            'Eliminar columnas con >70% missing',
            'Validación cruzada con múltiples fuentes'
        ]
    },
    'Complejidad Técnica': {
        'probabilidad': 'Media',
        'impacto': 'Medio',
        'descripcion': 'Kedro + Airflow + DVC + Docker puede ser complejo',
        'mitigacion': [
            'Implementación incremental por evaluación parcial',
            'Documentación exhaustiva paso a paso',
            'Testing continuo de componentes',
            'Consultar documentación oficial'
        ]
    },
    'Tiempo Limitado': {
        'probabilidad': 'Media',
        'impacto': 'Alto',
        'descripcion': '4 semanas puede ser ajustado para cada evaluación',
        'mitigacion': [
            'Planificación semanal estricta',
            'Distribución equitativa de trabajo',
            'Commits frecuentes y pequeños',
            'Priorizar requisitos obligatorios'
        ]
    },
    'Integración de Datasets': {
        'probabilidad': 'Media',
        'impacto': 'Medio',
        'descripcion': '4 datasets con diferentes granularidades',
        'mitigacion': [
            'Merge incremental y validado',
            'Tests de integridad de datos',
            'Documentar decisiones de integración',
            'Validación cruzada de resultados'
        ]
    },
    'Rendimiento de Modelos': {
        'probabilidad': 'Baja',
        'impacto': 'Alto',
        'descripcion': 'Modelos pueden no alcanzar métricas objetivo',
        'mitigacion': [
            'Feature engineering exhaustivo',
            'Probar múltiples algoritmos (≥5 por tipo)',
            'Optimización de hiperparámetros',
            'Ensemble methods si es necesario'
        ]
    },
    'Reproducibilidad': {
        'probabilidad': 'Baja',
        'impacto': 'Alto',
        'descripcion': 'Proyecto puede no ser reproducible por terceros',
        'mitigacion': [
            'Docker para ambiente consistente',
            'requirements.txt actualizado',
            'Seeds fijos para aleatoriedad',
            'Documentación detallada de setup'
        ]
    }
}

# Mostrar riesgos
for riesgo_nombre, riesgo_info in riesgos.items():
    print(f"\n⚠️ RIESGO: {riesgo_nombre}")
    print("   " + "-"*65)
    print(f"   Probabilidad: {riesgo_info['probabilidad']}")
    print(f"   Impacto: {riesgo_info['impacto']}")
    print(f"\n   Descripción:")
    print(f"      {riesgo_info['descripcion']}")
    print(f"\n   🛡️ Estrategias de Mitigación:")
    for i, estrategia in enumerate(riesgo_info['mitigacion'], 1):
        print(f"      {i}. {estrategia}")

# Matriz de riesgos
print("\n\n📊 MATRIZ DE RIESGOS (Probabilidad × Impacto):")
print("="*70)

matriz_riesgos = pd.DataFrame({
    'Riesgo': list(riesgos.keys()),
    'Probabilidad': [r['probabilidad'] for r in riesgos.values()],
    'Impacto': [r['impacto'] for r in riesgos.values()],
    'Prioridad': [
        'CRÍTICO' if r['probabilidad'] == 'Alta' and r['impacto'] == 'Alto' else
        'ALTO' if (r['probabilidad'] == 'Media' and r['impacto'] == 'Alto') or 
                  (r['probabilidad'] == 'Alta' and r['impacto'] == 'Medio') else
        'MEDIO' if r['probabilidad'] == 'Media' and r['impacto'] == 'Medio' else
        'BAJO'
        for r in riesgos.values()
    ]
})

display(matriz_riesgos)
# Out:
# ...
# 8. RIESGOS Y ESTRATEGIAS DE MITIGACIÓN
# ...
#
# ⚠️ RIESGO: Calidad de Datos
#    -----------------------------------------------------------------
#    Probabilidad: Alta
#    Impacto: Alto
#
#    Descripción:
#       Missing values >50% en algunas columnas críticas
#
#    🛡️ Estrategias de Mitigación:
#       1. Estrategias diferenciadas de imputación
#       2. Forward-fill para series temporales
#       3. Eliminar columnas con >70% missing
#       4. Validación cruzada con múltiples fuentes
#
# ⚠️ RIESGO: Complejidad Técnica
#    -----------------------------------------------------------------
#    Probabilidad: Media
#    Impacto: Medio
#
#    Descripción:
#       Kedro + Airflow + DVC + Docker puede ser complejo
#
#    🛡️ Estrategias de Mitigación:
#       1. Implementación incremental por evaluación parcial
#       2. Documentación exhaustiva paso a paso
#       3. Testing continuo de componentes
#       4. Consultar documentación oficial
#
# ⚠️ RIESGO: Tiempo Limitado
# ...

# %% [markdown]
# ---
# ## 9. RESUMEN EJECUTIVO
# ---

# %%
# =============================================================================
# 9. RESUMEN EJECUTIVO - FASE 1
# =============================================================================

print("\n" + "="*70)
print("9. RESUMEN EJECUTIVO - BUSINESS UNDERSTANDING")
print("="*70)

resumen = f"""
{'='*70}
PROYECTO: Sistema Predictivo de Preparación para Pandemias
{'='*70}

🦠 PROBLEMA:
   Falta de herramientas objetivas y basadas en datos para predecir
   qué países estarán mejor preparados ante futuras pandemias.

💡 SOLUCIÓN PROPUESTA:
   Sistema de Machine Learning con 3 componentes principales:

   1. CLASIFICACIÓN: Nivel de preparación (Alto/Medio/Bajo)
      → Target: preparedness_level
      → Métrica objetivo: Accuracy > 70%

   2. REGRESIÓN: Capacidad del sistema de salud (Score 0-100)
      → Target: healthcare_capacity_score
      → Métrica objetivo: R² > 0.6

   3. CLUSTERING: Arquetipos estratégicos de respuesta (5-7 grupos)
      → Técnicas: K-Means, DBSCAN, Hierarchical
      → Métrica objetivo: Silhouette Score > 0.5

📊 DATOS DISPONIBLES:
   • 4 datasets principales
   • ~750,000 registros totales
   • 200+ países cubiertos
   • Período: 2020-2023 (3+ años)
   • Variables: ~120 únicas

💻 TECNOLOGÍA:
   • Framework: Kedro 0.18.14
   • ML: scikit-learn
   • MLOps: DVC + Airflow + Docker (EP2)
   • Visualización: matplotlib, seaborn, plotly

⏰ TIMELINE:
   • EP1 (Semanas 1-4): Kedro + CRISP-DM Fases 1-3
   • EP2 (Semanas 5-8): Supervisado + MLOps
   • EP3 (Semanas 9-12): No Supervisado + Integración

🎯 VALOR ESPERADO:

   Para OMS y organizaciones internacionales:
   → Priorización objetiva de recursos limitados
   → Monitoreo continuo de preparación global
   → Identificación temprana de vulnerabilidades

   Para gobiernos nacionales:
   → Diagnóstico de fortalezas y debilidades
   → Benchmarking con países similares
   → Guía para inversión en salud pública

   Para investigadores:
   → Base de conocimiento reproducible
   → Framework extensible para nuevas pandemias
   → Metodología científica validada

✅ CRITERIOS DE ÉXITO:

   Técnicos:
   ✓ kedro run ejecuta sin errores
   ✓ Código reproducible 100%
   ✓ Documentación completa

   De Negocio:
   ✓ Accuracy > 70% (clasificación)
   ✓ R² > 0.6 (regresión)
   ✓ Insights accionables

   Académicos:
   ✓ Nota objetivo: 7.0 por evaluación
   ✓ Cumplimiento de rúbrica 100%
   ✓ Trabajo balanceado en equipo

{'='*70}
PRÓXIMA FASE: Comprensión de los Datos (EDA)
{'='*70}
"""

print(resumen)

print("\n" + "="*70)
print("✅ FASE 1 COMPLETADA: BUSINESS UNDERSTANDING")
print("="*70)
print("\n📊 Estado del proyecto:")
print("   ✓ Problema de negocio definido")
print("   ✓ Objetivos SMART establecidos")
print("   ✓ Stakeholders identificados")
print("   ✓ Targets definidos")
print("   ✓ Recursos disponibles validados")
print("   ✓ Plan de proyecto estructurado")
print("   ✓ Criterios de éxito claros")
print("   ✓ Riesgos analizados")
print("\n📅 Próximo paso: Notebook 2 - Data Understanding (EDA)")
print("="*70)
# Out:
# ...
# 9. RESUMEN EJECUTIVO - BUSINESS UNDERSTANDING
# ...
#
# ...
# PROYECTO: Sistema Predictivo de Preparación para Pandemias
# ...
#
# 🦠 PROBLEMA:
#    Falta de herramientas objetivas y basadas en datos para predecir
#    qué países estarán mejor preparados ante futuras pandemias.
#
# 💡 SOLUCIÓN PROPUESTA:
#    Sistema de Machine Learning con 3 componentes principales:
#
#    1. CLASIFICACIÓN: Nivel de preparación (Alto/Medio/Bajo)
#       → Target: preparedness_level
#       → Métrica objetivo: Accuracy > 70%
#
#    2. REGRESIÓN: Capacidad del sistema de salud (Score 0-100)
#       → Target: healthcare_capacity_score
#       → Métrica objetivo: R² > 0.6
#
#    3. CLUSTERING: Arquetipos estratégicos de respuesta (5-7 grupos)
#       → Técnicas: K-Means, DBSCAN, Hierarchical
#       → Métrica objetivo: Silhouette Score > 0.5
#
# 📊 DATOS DISPONIBLES:
#    • 4 datasets principales
#    • ~750,000 registros totales
#    • 200+ países cubiertos
#    • Período: 2020-2023 (3+ años)
#    • Variables: ~120 únicas
# ...

# %%
# =============================================================================
# 10. GUARDAR RESUMEN (OPCIONAL)
# =============================================================================

# Crear resumen estructurado para referencia futura
business_understanding_summary = {
    'fecha': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    'proyecto': 'Predicción y Preparación de Pandemias',
    'evaluacion': 'Parcial 1 - Business Understanding',
    'problema': 'Falta de sistema predictivo objetivo para preparación pandémica',
    'solucion': 'Sistema ML con clasificación + regresión + clustering',
    'targets': {
        'clasificacion': 'preparedness_level (Alto/Medio/Bajo)',
        'regresion': 'healthcare_capacity_score (0-100)'
    },
    'datos': {
        'datasets': 4,
        'registros_aprox': 750000,
        'paises': 200,
        'periodo': '2020-2023'
    },
    'metricas_objetivo': {
        'accuracy_clasificacion': '>70%',
        'r2_regresion': '>0.6',
        'silhouette_clustering': '>0.5'
    },
    'nota_objetivo': 7.0,
    'completado': True
}

print("\n📄 Resumen del Business Understanding:")
print("="*70)
for key, value in business_understanding_summary.items():
    if isinstance(value, dict):
        print(f"\n{key.upper()}:")
        for k, v in value.items():
            print(f"   {k}: {v}")
    else:
        print(f"{key}: {value}")

print("\n✅ Resumen guardado en memoria")
print("\n🎉 ¡NOTEBOOK 1 COMPLETADO EXITOSAMENTE!")
print("="*70)
# Out:
# 📄 Resumen del Business Understanding:
# ...
# fecha: 2025-11-23 14:33:08
# proyecto: Predicción y Preparación de Pandemias
# evaluacion: Parcial 1 - Business Understanding
# problema: Falta de sistema predictivo objetivo para preparación pandémica
# solucion: Sistema ML con clasificación + regresión + clustering
#
# TARGETS:
#    clasificacion: preparedness_level (Alto/Medio/Bajo)
#    regresion: healthcare_capacity_score (0-100)
#
# DATOS:
#    datasets: 4
#    registros_aprox: 750000
#    paises: 200
#    periodo: 2020-2023
#
# METRICAS_OBJETIVO:
#    accuracy_clasificacion: >70%
#    r2_regresion: >0.6
#    silhouette_clustering: >0.5
# nota_objetivo: 7.0
# completado: True
#
# ✅ Resumen guardado en memoria
#
# 🎉 ¡NOTEBOOK 1 COMPLETADO EXITOSAMENTE!
# ...
